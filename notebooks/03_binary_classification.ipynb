# %%
import os
import sys

from matplotlib.style.core import library

r_path = r'C:\Program Files\R\R-4.5.2'
os.environ['R_HOME'] = r_path
os.environ['PATH'] = os.path.join(r_path, 'bin', 'x64') + os.pathsep + os.environ['PATH']

import rpy2.robjects as robjects
from rpy2.robjects.packages import importr
import pandas as pd

project_root = os.path.abspath('..')
if project_root not in sys.path:
    sys.path.append(project_root)

# %load_ext rpy2.ipython
try:
    ggplot2 = importr('ggplot2')
    print("ggplot cargado correctamente")
except Exception as e:
    print(f"Error al cargar ggplot: {e}")
# Out:
# ggplot cargado correctamente

# %%
df = pd.read_csv(filepath_or_buffer="../data/processed/imdb_with_sentiment.csv", sep=",")

# %%
df
# Out:
#                                             Title    Year  Duration (min)  \
# 0                                 The Idea of You  2023.0           115.0
# 1               Kingdom of the Planet of the Apes  2023.0           145.0
# 2                                       Unfrosted  2023.0            97.0
# 3                                    The Fall Guy  2023.0           126.0
# 4                                     Challengers  2023.0           131.0
# ...                                           ...     ...             ...
# 9331                   The Greatest Show on Earth  2020.0           152.0
# 9332  Berserk: Ougon Jidai-hen I - Haou no Tamago  2020.0            76.0
# 9333                                   Is-slottet  2020.0            78.0
# 9334                                 Loving Pablo  2020.0           123.0
# 9335                        Un homme et une femme  2020.0           102.0
#
#                              Genre  Rating  Metascore  \
# ...

# %%
# %%R
